# %% [markdown]
# # Train
#
# Based on [the example](https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/scikit_learn_inference_pipeline/Inference%20Pipeline%20with%20Scikit-learn%20and%20Linear%20Learner.ipynb).

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
bucket = 'task-bucket-2021'
prefix = 'sagemaker-sklearn-linearlearner'

# %% [markdown]
# # Upload the train data

# %%
WORK_DIRECTORY = "../data"

train_input = sagemaker_session.upload_data(
    path="{}/{}".format(WORK_DIRECTORY, "train.csv"),
    bucket=bucket,
    key_prefix="{}/{}".format(prefix, "train"),
)

# %% [markdown]
# # Create SageMaker Scikit Estimator for preprocessing

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = "../preprocess/preprocess.py"

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    instance_type="ml.m4.xlarge",
    sagemaker_session=sagemaker_session,
)

# %%
sklearn_preprocessor.fit({"train": train_input})
# Out:
# 2021-07-18 22:01:58 Starting - Starting the training job...
# 2021-07-18 22:02:21 Starting - Launching requested ML instancesProfilerReport-1626645718: InProgress
# ...
# 2021-07-18 22:02:49 Starting - Preparing the instances for training.........
# 2021-07-18 22:04:22 Downloading - Downloading input data...
# 2021-07-18 22:04:42 Training - Downloading the training image...
# 2021-07-18 22:05:22 Uploading - Uploading generated training model
# 2021-07-18 22:05:22 Completed - Training job completed
# 2021-07-18 22:05:10,193 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-07-18 22:05:10,197 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:05:10,208 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-07-18 22:05:10,563 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:05:12,003 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:05:12,018 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:05:12,030 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-07-18-22-01-58-120",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-526517470076/sagemaker-scikit-learn-2021-07-18-22-01-58-120/source/sourcedir.tar.gz",
#     "module_name": "preprocess",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "preprocess.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=preprocess.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=preprocess
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-526517470076/sagemaker-scikit-learn-2021-07-18-22-01-58-120/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-07-18-22-01-58-120","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-526517470076/sagemaker-scikit-learn-2021-07-18-22-01-58-120/source/sourcedir.tar.gz","module_name":"preprocess","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"preprocess.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python preprocess.py
#
#
# saved model!
# 2021-07-18 22:05:14,394 sagemaker-containers INFO     Reporting training SUCCESS
# Training seconds: 64
# Billable seconds: 64

# %%
# Define a SKLearn Transformer from the trained SKLearn Estimator
transformer = sklearn_preprocessor.transformer(
    instance_count=1, instance_type="ml.m4.xlarge", assemble_with="Line", accept="text/csv",
    strategy='SingleRecord', max_payload=20
)

# %%
# Preprocess training input
transformer.transform(train_input, content_type="text/csv")
print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
transformer.wait()
preprocessed_train = transformer.output_path
# Out:
# ...............................2021-07-18 22:10:38,875 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:10:38,878 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-07-18 22:10:38,879 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2021-07-18 22:10:39,023 INFO - sagemaker-containers - Module preprocess does not provide a setup.py.
# Generating setup.py
# 2021-07-18 22:10:39,023 INFO - sagemaker-containers - Generating setup.cfg
# 2021-07-18 22:10:39,023 INFO - sagemaker-containers - Generating MANIFEST.in
# 2021-07-18 22:10:39,023 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: preprocess
#   Building wheel for preprocess (setup.py): started
#   Building wheel for preprocess (setup.py): finished with status 'done'
#   Created wheel for preprocess: filename=preprocess-1.0.0-py2.py3-none-any.whl size=6729 sha256=383cb63aeb795a05410f08bb1537e830cd080cb0732189c0b7c411969751e986
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-4cf1kz7f/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built preprocess
# Installing collected packages: preprocess
# Successfully installed preprocess-1.0.0
# [2021-07-18 22:10:41 +0000] [36] [INFO] Starting gunicorn 20.0.4
# [2021-07-18 22:10:41 +0000] [36] [INFO] Listening at: unix:/tmp/gunicorn.sock (36)
# [2021-07-18 22:10:41 +0000] [36] [INFO] Using worker: gevent
# [2021-07-18 22:10:41 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-07-18 22:10:41 +0000] [40] [INFO] Booting worker with pid: 40
# [2021-07-18 22:10:41 +0000] [44] [INFO] Booting worker with pid: 44
# [2021-07-18 22:10:41 +0000] [45] [INFO] Booting worker with pid: 45
# 2021-07-18 22:10:44,796 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [18/Jul/2021:22:10:45 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [18/Jul/2021:22:10:45 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 2021-07-18 22:10:46,086 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2021-07-18T22:10:45.546:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=20, BatchStrategy=SINGLE_RECORD
# [2021-07-18 22:11:46 +0000] [36] [CRITICAL] WORKER TIMEOUT (pid:40)
# [2021-07-18 22:11:46 +0000] [36] [CRITICAL] WORKER TIMEOUT (pid:40)
# 2021/07/18 22:11:46 [error] 13#13: *4 upstream prematurely closed connection while reading response header from upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/invocations", host: "169.254.255.131:8080"
# 169.254.255.130 - - [18/Jul/2021:22:11:46 +0000] "POST /invocations HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-07-18 22:11:46 +0000] [40] [INFO] Worker exiting (pid: 40)
# 2021-07-18 22:11:46,146 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# [2021-07-18 22:11:46 +0000] [68] [INFO] Booting worker with pid: 68
# 2021/07/18 22:11:46 [error] 13#13: *4 upstream prematurely closed connection while reading response header from upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/invocations", host: "169.254.255.131:8080"
# 169.254.255.130 - - [18/Jul/2021:22:11:46 +0000] "POST /invocations HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-07-18 22:11:46 +0000] [40] [INFO] Worker exiting (pid: 40)
# 2021-07-18 22:11:46,146 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# [2021-07-18 22:11:46 +0000] [68] [INFO] Booting worker with pid: 68
# [2021-07-18 22:13:45 +0000] [36] [CRITICAL] WORKER TIMEOUT (pid:45)
# 2021/07/18 22:13:45 [error] 13#13: *4 upstream prematurely closed connection while reading response header from upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/invocations", host: "169.254.255.131:8080"
# 169.254.255.130 - - [18/Jul/2021:22:13:45 +0000] "POST /invocations HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-07-18 22:13:45 +0000] [45] [INFO] Worker exiting (pid: 45)
# 2021-07-18 22:13:45,941 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# [2021-07-18 22:13:46 +0000] [82] [INFO] Booting worker with pid: 82
# [2021-07-18 22:13:45 +0000] [36] [CRITICAL] WORKER TIMEOUT (pid:45)
# 2021/07/18 22:13:45 [error] 13#13: *4 upstream prematurely closed connection while reading response header from upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/invocations", host: "169.254.255.131:8080"
# 169.254.255.130 - - [18/Jul/2021:22:13:45 +0000] "POST /invocations HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-07-18 22:13:45 +0000] [45] [INFO] Worker exiting (pid: 45)
# 2021-07-18 22:13:45,941 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# [2021-07-18 22:13:46 +0000] [82] [INFO] Booting worker with pid: 82
#
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: Bad HTTP status received from algorithm: 502
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv:
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: Message:
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: <html>#015
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: <head><title>502 Bad Gateway</title></head>#015
# 2021-07-18T22:14:45.248:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: <body bgcolor="white">#015
# 2021-07-18T22:14:45.249:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: <center><h1>502 Bad Gateway</h1></center>#015
# 2021-07-18T22:14:45.249:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: <hr><center>nginx/1.14.0 (Ubuntu)</center>#015
# 2021-07-18T22:14:45.249:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: </body>#015
# 2021-07-18T22:14:45.249:[sagemaker logs]: task-bucket-2021/sagemaker-sklearn-linearlearner/train/train.csv: </html>#015
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-44-95e18beb71f6> in <module>
#       1 # Preprocess training input
# ----> 2 transformer.transform(train_input, content_type="text/csv")
#       3 print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
#       4 transformer.wait()
#       5 preprocessed_train = transformer.output_path
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in transform(self, data, data_type, content_type, compression_type, split_type, job_name, input_filter, output_filter, join_source, experiment_config, model_client_config, wait, logs)
#     216
#     217         if wait:
# --> 218             self.latest_transform_job.wait(logs=logs)
#     219
#     220     def delete_model(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/transformer.py in wait(self, logs)
#     412     def wait(self, logs=True):
#     413         if logs:
# --> 414             self.sagemaker_session.logs_for_transform_job(self.job_name, wait=True)
#     415         else:
#     416             self.sagemaker_session.wait_for_transform_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_transform_job(self, job_name, wait, poll)
#    3849
#    3850         if wait:
# -> 3851             self._check_job_status(job_name, description, "TransformJobStatus")
#    3852             if dot:
#    3853                 print()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3243                 ),
#    3244                 allowed_statuses=["Completed", "Stopped"],
# -> 3245                 actual_status=status,
#    3246             )
#    3247
#
# UnexpectedStatusException: Error for Transform job sagemaker-scikit-learn-2021-07-18-22-05-40-395: Failed. Reason: AlgorithmError: See job logs for more information

# %% [markdown]
# # Fit a LinearLearner Model with the preprocessed data

# %%
import boto3
from sagemaker.image_uris import retrieve

ll_image = retrieve("linear-learner", boto3.Session().region_name)

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = "s3://{}/{}/{}/{}".format(
    bucket, prefix, s3_ll_output_key_prefix, "ll_model"
)

ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    volume_size=5,
    max_run=3600,
    input_mode="File",
    output_path=s3_ll_output_location,
    sagemaker_session=sagemaker_session,
)

ll_estimator.set_hyperparameters(predictor_type="binary_classifier", feature_dim=171, wd=1.0) # To reduce overfitting due to multicollinearity, set L2 regularization.

ll_train_data = sagemaker.inputs.TrainingInput(
    preprocessed_train,
    distribution="FullyReplicated",
    content_type="text/csv",
    s3_data_type="S3Prefix",
)

data_channels = {"train": ll_train_data}
ll_estimator.fit(inputs=data_channels, logs=True)

# %% [markdown]
# # Create an Inference Pipeline with Scikit preprocessor and Linear Learner

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = "inference-pipeline-" + timestamp_prefix
endpoint_name = "inference-pipeline-ep-" + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, role=role, models=[scikit_learn_inferencee_model, linear_learner_model]
)

sm_model.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge", endpoint_name=endpoint_name)

# %% [markdown]
# # Test the endpoint

# %%
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer

predictor = Predictor(
    endpoint_name=endpoint_name, sagemaker_session=sagemaker_session, serializer=CSVSerializer()
)


test = pd.read_csv("{}/{}".format(WORK_DIRECTORY, "test.csv"))
label = 'default'
variables = [x for x in test.columns if x != 'uuid' and x != label]
test_X, test_y = test[variables], test[label].values

predictions = []
for array in np.array_split(test_X, 100):
    result = predictor.predict(array)
    predictions += [r["predicted_label"] for r in result["predictions"]]

predictions = np.array(predictions)

# %%
from sklearn.metrics import classification_report

print(classification_report(test_y, predictions))
